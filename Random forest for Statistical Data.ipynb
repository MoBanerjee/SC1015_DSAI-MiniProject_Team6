# %% [markdown]
# # Random Forest
#
# ## Statistical Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.metrics import mean_absolute_error,mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# %%
train = pd.read_csv('Test Train Data/train.csv')
test = pd.read_csv('Test Train Data/test.csv')

# %%
train.head()
# Out:
#    Unnamed: 0 release_date  explicit                    name  \
# 0       18937   2015-11-20         0        Love In The Dark
# 1       37992   2016-03-18         0        Varanda Suspensa
# 2       38792   2014-12-03         0            Wonder Woman
# 3       36021   1986-06-21         0              Fé Nenhuma
# 4       19757   1959-01-01         0  Cheerful Little Earful
#
#                                                Lyric language  duration_ms  \
# 0  Take your eyes off of me so I can leave\nI'm f...       en     0.121984
# 1  Descansar a vista\nAté onde a vista alcança\nD...       pt     0.123003
# 2  Reminiscing\nTouching all the places that your...       en     0.117848
# 3  Não levo fé nenhuma em nada!\nNão levo fé nenh...       pt     0.067879
# 4  There's a cheerful little earful\nGosh I miss ...       en     0.051705
#
#    explicit.1  danceability    energy  ...  loudness  mode  speechiness  \
# 0         0.0      0.501012  0.322986  ...  0.774394   0.0     0.028676
# 1         0.0      0.787449  0.750995  ...  0.776261   1.0     0.045255
# 2         0.0      0.770243  0.825996  ...  0.788657   1.0     0.037122
# 3         0.0      0.437247  0.968999  ...  0.793397   1.0     0.096767
# 4         0.0      0.536437  0.369987  ...  0.708952   1.0     0.068405
#
#    acousticness  instrumentalness  liveness   valence     tempo  \
# 0      0.538153          0.000000  0.101778  0.140562  0.450878
# 1      0.124498          0.428858  0.065667  0.967871  0.575165
# 2      0.015863          0.000034  0.068398  0.894578  0.493007
# 3      0.247992          0.000305  0.823997  0.539157  0.582557
# 4      0.639558          0.000000  0.357691  0.842369  0.570275
#
#    time_signature  popularity
# 0             0.8    0.587629
# 1             0.8    0.525773
# 2             0.8    0.422680
# 3             0.8    0.216495
# 4             0.8    0.175258
#
# [5 rows x 21 columns]

# %%
train.describe()
# Out:
#          Unnamed: 0      explicit   duration_ms    explicit.1  danceability  \
# count  33536.000000  33536.000000  33536.000000  33536.000000  33536.000000
# mean   20961.947251      0.070104      0.097053      0.070104      0.568106
# std    12089.113328      0.255326      0.036189      0.255326      0.165985
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%    10493.750000      0.000000      0.075129      0.000000      0.455466
# 50%    20945.500000      0.000000      0.092321      0.000000      0.575911
# 75%    31445.500000      0.000000      0.112275      0.000000      0.688259
# max    41920.000000      1.000000      1.000000      1.000000      0.997976
#
#              energy           key      loudness          mode   speechiness  \
# count  33536.000000  33536.000000  33536.000000  33536.000000  33536.000000
# mean       0.588653      0.477181      0.721351      0.693076      0.073698
# std        0.242595      0.320451      0.090516      0.461224      0.084889
# min        0.000000      0.000000      0.100008      0.000000      0.000000
# 25%        0.411988      0.181818      0.666562      0.000000      0.034411
# 50%        0.605992      0.454545      0.735548      1.000000      0.044108
# 75%        0.790996      0.727273      0.789270      1.000000      0.070073
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        acousticness  instrumentalness      liveness       valence  \
# count  33536.000000      33536.000000  33536.000000  33536.000000
# mean       0.353719          0.082625      0.188309      0.551111
# std        0.328690          0.220685      0.160881      0.255761
# min        0.000000          0.000000      0.000000      0.000000
# 25%        0.040261          0.000000      0.087718      0.342369
# 50%        0.254016          0.000035      0.125043      0.560241
# 75%        0.642570          0.006736      0.246424      0.768072
# max        1.000000          1.000000      1.000000      1.000000
#
#               tempo  time_signature    popularity
# count  33536.000000    33536.000000  33536.000000
# mean       0.493535        0.782729      0.402137
# std        0.120806        0.074265      0.190726
# min        0.000000        0.000000      0.000000
# 25%        0.399065        0.800000      0.278351
# 50%        0.486821        0.800000      0.412371
# 75%        0.567152        0.800000      0.536082
# max        1.000000        1.000000      0.989691

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33536 entries, 0 to 33535
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        33536 non-null  int64
#  1   release_date      33536 non-null  object
#  2   explicit          33536 non-null  int64
#  3   name              33536 non-null  object
#  4   Lyric             33536 non-null  object
#  5   language          33536 non-null  object
#  6   duration_ms       33536 non-null  float64
#  7   explicit.1        33536 non-null  float64
#  8   danceability      33536 non-null  float64
#  9   energy            33536 non-null  float64
#  10  key               33536 non-null  float64
#  11  loudness          33536 non-null  float64
#  12  mode              33536 non-null  float64
#  13  speechiness       33536 non-null  float64
#  14  acousticness      33536 non-null  float64
#  15  instrumentalness  33536 non-null  float64
#  16  liveness          33536 non-null  float64
#  17  valence           33536 non-null  float64
#  18  tempo             33536 non-null  float64
#  19  time_signature    33536 non-null  float64
#  20  popularity        33536 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 5.4+ MB

# %%
numerical_columns = ['duration_ms', 'tempo', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence']

# %%
X_train = train[numerical_columns]
y_train = train['popularity']
X_test = test[numerical_columns]
y_test = test['popularity']

# %%
regressor = RandomForestRegressor(n_estimators = 100)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
df
# Out:
#       Real Values  Predicted Values
# 0        0.072165          0.320412
# 1        0.515464          0.380515
# 2        0.309278          0.439897
# 3        0.597938          0.468144
# 4        0.329897          0.347423
# ...           ...               ...
# 8380     0.711340          0.453299
# 8381     0.422680          0.429485
# 8382     0.000000          0.177423
# 8383     0.577320          0.594742
# 8384     0.484536          0.425979
#
# [8385 rows x 2 columns]

# %% [markdown]
# ## Model Performance

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.1257995799240585

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 0.1596036211433357
