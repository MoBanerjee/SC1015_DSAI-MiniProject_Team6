# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sb

# %%
dataset = pandas.read_csv('Final Datasets/dataCleaned.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41921 entries, 0 to 41920
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   release_date      41921 non-null  object
#  1   explicit          41921 non-null  int64
#  2   name              41921 non-null  object
#  3   Lyric             41921 non-null  object
#  4   language          41921 non-null  object
#  5   popularity        41921 non-null  float64
#  6   duration_ms       41921 non-null  float64
#  7   explicit.1        41921 non-null  float64
#  8   danceability      41921 non-null  float64
#  9   energy            41921 non-null  float64
#  10  key               41921 non-null  float64
#  11  loudness          41921 non-null  float64
#  12  mode              41921 non-null  float64
#  13  speechiness       41921 non-null  float64
#  14  acousticness      41921 non-null  float64
#  15  instrumentalness  41921 non-null  float64
# ...

# %%
dataset.head()
# Out:
#   release_date  explicit                name  \
# 0   1922-02-22         0               Carve
# 1         1922         0           Ave Maria
# 2         1922         0   How High the Moon
# 3         1922         0               Marta
# 4         1922         0  Carol of the Bells
#
#                                                Lyric language  popularity  \
# 0  There doing something rather curious\nWith the...       en    0.061856
# 1  She was lost\nIn so many different ways\nOut i...       en    0.000000
# 2  Somewhere there's music\nHow faint the tune\nS...       en    0.000000
# 3  Marta se viste en mi habitación\nson las 6 de ...       es    0.000000
# 4  (sopranos)\nHark! how the bells\nSweet silver ...       en    0.000000
#
#    duration_ms  explicit.1  danceability    energy       key  loudness  mode  \
# 0     0.050481         0.0      0.652834  0.444989  0.000000  0.639378   1.0
# 1     0.073874         0.0      0.229757  0.260985  0.454545  0.660248   1.0
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### This scatterplot shows relationship between **duration of song and its popularity**. There seems to be a **very poor positive correlation**

# %%
sb.scatterplot(x=dataset['duration_ms'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='duration_ms', ylabel='popularity'>

# %% [markdown]
# ### This scatterplot shows relationship between **danceability of song and its popularity**. There seems to be a **very poor positive correlation**

# %%
sb.scatterplot(x=dataset['danceability'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='danceability', ylabel='popularity'>

# %% [markdown]
# ### This categorical boxplot shows relationship between the **categorical variable key and the numerical variable popularity of song**.Each boxplot represents the distribution of popularity values for different categories of the key. There seems to be a **very poor positive correlation**

# %%
sb.boxplot(x=dataset['key'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='key', ylabel='popularity'>

# %% [markdown]
# ### This scatterplot shows relationship between **energy and its popularity**. There seems to be a **poor positive correlation**

# %%
sb.scatterplot(x=dataset['energy'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='energy', ylabel='popularity'>

# %% [markdown]
# ### This scatterplot shows relationship between **loudness of song and its popularity**. There seems to be a **fairly positive correlation**

# %%
sb.scatterplot(x=dataset['loudness'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='loudness', ylabel='popularity'>

# %% [markdown]
# ### This categorical boxplot shows relationship between the **categorical variable mode and the numerical variable popularity of song**.Each boxplot represents the distribution of popularity values for different categories of the mode. There seems to be a **very poor negative correlation**

# %%
sb.boxplot(x=dataset['mode'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='mode', ylabel='popularity'>

# %% [markdown]
# ### This scatterplot shows relationship between **speechiness of song and its popularity**. There seems to be a **very poor positive correlation**

# %%
sb.scatterplot(x=dataset['speechiness'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='speechiness', ylabel='popularity'>

# %% [markdown]
# ### This scatterplot shows relationship between **acoustiness of song and its popularity**. There seems to be a **fairly positive correlation**

# %%
sb.scatterplot(x=dataset['acousticness'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='acousticness', ylabel='popularity'>

# %% [markdown]
# This scatterplot shows relationship between **instrumentalness of song and its popularity**. There seems to be a **poor negative correlation**

# %%
sb.scatterplot(x=dataset['instrumentalness'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='instrumentalness', ylabel='popularity'>

# %% [markdown]
# This scatterplot shows relationship between **liveness of song and its popularity**. There seems to be a **very poor negative correlation**

# %%
sb.scatterplot(x=dataset['liveness'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='liveness', ylabel='popularity'>

# %% [markdown]
# ### This scatterplot shows relationship between **valence of song and its popularity**. There seems to be a **very poor negative correlation**

# %%
sb.scatterplot(x=dataset['valence'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='valence', ylabel='popularity'>

# %% [markdown]
# ### This scatterplot shows relationship between **tempo of song and its popularity**. There seems to be a **very poor positive correlation**

# %%
sb.scatterplot(x=dataset['tempo'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='tempo', ylabel='popularity'>

# %% [markdown]
# ### This categorical boxplot shows relationship between the **categorical variable time_signature and the numerical variable popularity of song**.Each boxplot represents the distribution of popularity values for different categories of the time_signature. There seems to be a **very poor positive correlation**

# %%
sb.boxplot(x=dataset['time_signature'], y=dataset['popularity'])
# Out:
# <AxesSubplot: xlabel='time_signature', ylabel='popularity'>

# %% [markdown]
# ## Numerical dataset

# %% [markdown]
# We have created a **new dataset** here called **data_numerical** combining **all those columns which are numerical** in order to find their correlation with popularity.

# %%
data_numerical = dataset[['popularity' ,'duration_ms', 'danceability', 'key', 'energy', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]

# %%
data_numerical.head()
# Out:
#    popularity  duration_ms  danceability       key    energy  loudness  mode  \
# 0    0.061856     0.050481      0.652834  0.000000  0.444989  0.639378   1.0
# 1    0.000000     0.073874      0.229757  0.454545  0.260985  0.660248   1.0
# 2    0.000000     0.072256      0.331984  0.000000  0.306986  0.676399   1.0
# 3    0.000000     0.073317      0.258097  0.000000  0.342987  0.722544   1.0
# 4    0.000000     0.122180      0.386640  0.909091  0.749995  0.675854   1.0
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.470282      0.676707          0.745491  0.144262  0.127510  0.430826
# 1     0.039833      0.997992          0.247495  0.090348  0.054116  0.488516
# 2     0.050469      0.992972          0.277555  0.203941  0.260040  0.481670
# 3     0.031804      0.990964          0.015331  0.321276  0.314257  0.415397
# 4     0.077372      0.123494          0.752505  0.724869  0.347390  0.615465
#
#    time_signature
# 0             0.6
# ...

# %%
data_numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41921 entries, 0 to 41920
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   popularity        41921 non-null  float64
#  1   duration_ms       41921 non-null  float64
#  2   danceability      41921 non-null  float64
#  3   key               41921 non-null  float64
#  4   energy            41921 non-null  float64
#  5   loudness          41921 non-null  float64
#  6   mode              41921 non-null  float64
#  7   speechiness       41921 non-null  float64
#  8   acousticness      41921 non-null  float64
#  9   instrumentalness  41921 non-null  float64
#  10  liveness          41921 non-null  float64
#  11  valence           41921 non-null  float64
#  12  tempo             41921 non-null  float64
#  13  time_signature    41921 non-null  float64
# dtypes: float64(14)
# memory usage: 4.5 MB

# %%
numerical_corr = {}
for i in data_numerical.columns:
    numerical_corr[i] = data_numerical[i].corr(data_numerical['popularity'])

# %% [markdown]
# ### Correlation between Popularity and Numerical values
#
# These are the **correlation values** which vary from -1 to 1.
# The **correlation coefficient** is a statistical measure that **ranges between -1 and +1**, where **-1 indicates a perfect negative correlation** (i.e., when one variable increases, the other decreases), **+1 indicates a perfect positive correlation** (i.e., when one variable increases, the other also increases), and **0 indicates no correlation** (i.e., the variables are independent of each other).

# %%
numerical_corr
# Out:
# {'popularity': 1.0,
#  'duration_ms': 0.12726734723383737,
#  'danceability': 0.14363369269803083,
#  'key': 0.01298152138671805,
#  'energy': 0.2681007570873563,
#  'loudness': 0.3205654991451591,
#  'mode': -0.04363950294661834,
#  'speechiness': 0.08734823310891537,
#  'acousticness': -0.34747721528203634,
#  'instrumentalness': -0.17040204772236883,
#  'liveness': -0.03325530814556405,
#  'valence': -0.043332211438375394,
#  'tempo': 0.05343940498273807,
#  'time_signature': 0.08250939848578888}

# %% [markdown]
# ### This is the **heatmap** showing the **correlation values which we calculated earlier visually**. The **lighter the colour of the box, the higher is the positive correlation** between two variables. **Darker colours** signify **stronger negative correlation**

# %%
plt.figure(figsize=(20,20))
sb.heatmap(data_numerical.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Natural Language Processing EDA - Lyrics

# %%
import re
import nltk
from nltk.corpus import stopwords
from collections import Counter
from nltk.stem import SnowballStemmer

# %%
# Downloading the nltk stopwords. "nltk.download()" was not working so I had to use the following code to download the stopwords.

import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
#stopwords.words('english') initializes a set of stopwords in English using the NLTK library.
stopwords = stopwords.words('english')

#initializes a stemming object that uses the Snowball algorithm for stemming
stemmer = SnowballStemmer('english')

def clean_text(text):
    #converts all the text to lowercase to ensure consistency in processing.
    text = text.lower()
    
    #removes all non-alphabetic characters and whitespace from the text string using regular expressions. The re.I|re.A flag makes the search case-insensitive and ASCII-only.
    text = re.sub(r'[^a-zA-Z\s]', '', text, re.I|re.A)
    tokens = text.split()
    
    #applies stemming to each token and removes any stopwords from the resulting list of stemmed tokens. The list comprehension here performs the stemming and filtering operations in one line.
    tokens = [stemmer.stem(token) for token in tokens if token not in stopwords]
    text = ' '.join(tokens)
    
    #returns the cleaned text string.
    return text

# %% [markdown]
# ### Text- Cleaning Function Description:
# Here, we are performing text cleaning function that uses the **Natural Language Toolkit (NLTK) library** in Python to preprocess a given text string.
#
# * **Stopwords** are common words that are usually removed from text data during preprocessing because they do not carry much meaning.
#
# * **Stemming** is the process of reducing a word to its base form (or stem) by removing affixes (prefixes, suffixes, etc.).
#
# * This function also involves **tokenization** that splits the text string into individual words or tokens.
#
# * Overall, this function is a simple yet effective way to preprocess text data by removing non-alphabetic characters, stopwords, and reducing words to their base forms. This can help improve the quality of the text data for further analysis.

# %%
dataset['Lyric Altered'] = dataset['Lyric'].apply(lambda x: clean_text(x))

# %% [markdown]
# Here, we are creating a **new column** in the dataset called **lenth** with the **length of each element x of the 'Lyric Altered' column**. After creating the column, we have performed EDA by creating a **box plot**.

# %%
dataset['lenth'] = dataset['Lyric Altered'].apply(lambda x: len(x))
sb.boxplot(x=dataset['lenth'])
# Out:
# <AxesSubplot: xlabel='lenth'>

# %% [markdown]
# ### Unique Songs
#
# Here we have plotted the **histogram plot** along with the **kernel density estimate** of **popularity index**.

# %%
#Unique songs

unique_songs = len(dataset['Lyric Altered'].unique())
print("Number of unique songs: ", unique_songs)

#Distribution of popularity index
sb.set(style="whitegrid")
plt.figure(figsize=(20,10))
sb.histplot(dataset['popularity'], kde=True)
plt.title('Distribution of song popularity')
plt.xlabel('Popularity Index')
plt.ylabel('Frequency')
# Out:
# Number of unique songs:  41799
# Text(0, 0.5, 'Frequency')

# %%
#counting the frequency of elements in the lyrics

word_counter = Counter()

for lyrics in dataset['Lyric Altered']:
    word_counter.update(lyrics.split())

# %%
#finding the top 20 common words

top_20_words = word_counter.most_common(20)
top_words, top_counts = zip(*top_20_words)

# %% [markdown]
# ### **Bar plot** of the **top 20 common words in the lyrics**

# %%
plt.figure(figsize=(20,10))
plt.bar(top_words, top_counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 words in the lyrics')
plt.xticks(rotation=45)

plt.show()
